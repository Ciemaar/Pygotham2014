# %%
cd test
# Out:
# /home/andriod/Pygotham2014/test

# %%
from data_access import get_file
from fund import FundsHolder
from portfolio import PortfoliosHolder
from quandl_streams import get_live
from simple_files import FileHolder
import pandas as pd

# %%
portfolios = PortfoliosHolder('portfolio')
funds = FundsHolder('funds')
model = FileHolder('model')
market = get_live(get_file("sys"), model)

# %%
funds.retirement.components
# Out:
#             instrument_type instrument  quantity  cost start_date  end_date
# position_id
# 1                        fx        eur       100   100   2009-5-2       NaN
# 2                     stock       AAPL       100   100   2009-5-2       NaN
#
# [2 rows x 6 columns]

# %%
funds.rip.components
# Out:
#             instrument_type instrument  quantity  cost  start_date  end_date
# position_id
# 1                     stock        SCI     23.84   NaN  2013-03-08       NaN
# 2                     stock       MATW     17.39   NaN  2013-03-08       NaN
# 3                     stock        CSV     11.80   NaN  2013-03-08       NaN
# 4                     stock         HI     11.01   NaN  2013-03-08       NaN
# 5                     stock        CHE     27.11   NaN  2013-03-08       NaN
# 6                     stock       GTIV      6.28   NaN  2013-03-08       NaN
# 7                     stock       BIOS      1.30   NaN  2013-03-08       NaN
# 8                     stock       AMED      1.27   NaN  2013-03-08       NaN
#
# [8 rows x 6 columns]

# %%
funds['retirement'].components
# Out:
#             instrument_type instrument  quantity  cost start_date  end_date
# position_id
# 1                        fx        eur       100   100   2009-5-2       NaN
# 2                     stock       AAPL       100   100   2009-5-2       NaN
#
# [2 rows x 6 columns]

# %%
market.fx['usd_eur'][-3:]
# Out:
#                 Rate  High (est)  Low (est)
# Date
# 2014-08-06  0.745930     0.75484    0.73713
# 2014-08-07  0.747634     0.75697    0.73841
# 2014-08-08  0.747993     0.00000    0.00000
#
# [3 rows x 3 columns]

# %%
market.stock.IBM['July-01-2014':'July-07-2014']
# Out:
#               Open     High     Low   Close   Volume  Ex-Dividend  \
# 2014-07-01  181.71  187.270  181.70  186.35  6628713            0
# 2014-07-02  186.35  188.990  186.17  188.39  5084454            0
# 2014-07-03  188.35  188.806  187.35  188.53  2421835            0
# 2014-07-04  188.35  188.806  187.35  188.53  2421835            0
# 2014-07-07  187.61  188.270  187.44  188.04  2958695            0
#
#             Split Ratio   Adj. Open   Adj. High    Adj. Low  Adj. Close  \
# 2014-07-01            1  180.641518  186.168824  180.631576  185.254234
# 2014-07-02            1  185.254234  187.878710  185.075292  187.282238
# 2014-07-03            1  187.242473  187.695792  186.248354  187.421415
# 2014-07-04            1  187.242473  187.695792  186.248354  187.421415
# 2014-07-07            1  186.506825  187.162944  186.337824  186.934296
#
#             Adj. Volume
# 2014-07-01      6628713
# 2014-07-02      5084454
# 2014-07-03      2421835
# 2014-07-04      2421835
# 2014-07-07      2958695
#
# [5 rows x 12 columns]

# %%
market.stock.GOOG.describe()
# Out:
#              Open        High         Low       Close          Volume  \
# count  101.000000  101.000000  101.000000  101.000000      101.000000
# mean   556.852079  561.052784  550.532045  556.068207  1964234.029703
# std     22.871772   22.555765   23.191910   22.585339  1267506.296244
# min    508.460000  516.680000  502.800000  509.960000     7900.000000
# 25%    538.250000  544.100000  529.560000  536.100000  1323775.000000
# 50%    559.620000  564.000000  554.250000  558.840000  1683900.000000
# 75%    574.650000  579.570000  566.135000  573.729900  2094600.000000
# max    599.990000  604.830000  592.500000  595.980000  6790900.000000
#
#        Ex-Dividend  Split Ratio   Adj. Open   Adj. High    Adj. Low  \
# count          101          101  101.000000  101.000000  101.000000
# mean             0            1  556.852079  561.052784  550.532045
# std              0            0   22.871772   22.555765   23.191910
# min              0            1  508.460000  516.680000  502.800000
# 25%              0            1  538.250000  544.100000  529.560000
# 50%              0            1  559.620000  564.000000  554.250000
# 75%              0            1  574.650000  579.570000  566.135000
# max              0            1  599.990000  604.830000  592.500000
#
#        Adj. Close     Adj. Volume
# count  101.000000      101.000000
# mean   556.068207  1964234.029703
# std     22.585339  1267506.296244
# min    509.960000     7900.000000
# 25%    536.100000  1323775.000000
# 50%    558.840000  1683900.000000
# 75%    573.729900  2094600.000000
# max    595.980000  6790900.000000
#
# [8 rows x 12 columns]
